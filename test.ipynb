# %%
import requests
import json

url = "/api/generate"

data = {
    "model": "mistral",
    "prompt": "Explain Python in simple words",
    "stream": False
}

response = requests.post(url, json=data)

result = response.json()

print(result["response"])
# Out:
#  Python is a programming language that allows computers to perform tasks automatically. It's designed to be easy for beginners but also powerful enough for professionals.
#
# In simple terms, imagine you are teaching a robot to do different jobs, like playing music, making drawings, or even managing a website. Python is the language you would use to explain step-by-step what tasks the robot should perform.
#
# It's called programming because it involves breaking down complex tasks into smaller, manageable steps (programs), and then teaching the computer to execute those steps one by one.
#
# Python is very popular among programmers due to its simplicity, flexibility, and wide range of applications. It's used in many areas, including web development, data analysis, artificial intelligence, machine learning, and more.

# %%
import requests
import json
def get_response(q="hi"):
    url = "http://localhost:11434/api/generate"

    data = {
        "model": "mistral",
        "prompt": q,
        "stream": False
    }

    response = requests.post(url, json=data)

    result = response.json()

    print(result["response"])

# %%
get_response()
# Out:
#  Hello! How can I help you today? Is there something specific you'd like to know or talk about? I'm here to answer your questions and engage in conversation.

# %%
get_response("who is elon musk")
# Out:
#  Elon Musk is a South African-born American entrepreneur and business magnate. He is the CEO and CTO of SpaceX, CEO of Neuralink, and CEO of Tesla, Inc., where he also holds the title of Product Architect for both companies. As of February 2021, he is the wealthiest person in the world, according to Forbes' real-time billionaire ranking.
#
# Musk founded X.com in 1999 (which later became PayPal), co-founded Tesla Inc. in 2003 and SpaceX in 2002. He acted as CEO of both companies till 2008, then continued to serve as CEO of Tesla and served as the chairman of SpaceX. In 2016, he co-founded Neuralink Corp., a neurotechnology company focused on developing brain–computer interfaces.
#
# Musk has gained prominence for his controversial public actions, including his advocacy for colonizing Mars, and for his use of Twitter to interact with the public and media personally. His influence extends beyond his businesses into popular culture, science fiction, and politics.

# %%
get_response("who is narendra modi ?")
# Out:
#  Narendra Modi is a prominent Indian politician who served as the Prime Minister of India from 2014 to the present. He was born on September 17, 1950, in Vadnagar, Gujarat. Before becoming Prime Minister, he served as the Chief Minister of Gujarat for three terms (from 2001 to 2014).
#
# Modi is a member of the Bharatiya Janata Party (BJP), a major political party in India. He has been credited with leading economic reforms and infrastructure development initiatives during his time as Chief Minister of Gujarat, which contributed significantly to his political success.
#
# As Prime Minister, Modi has focused on various key areas, such as improving the economy, strengthening national security, and implementing major policy initiatives like Demonetization and Goods and Services Tax (GST). He is known for his charismatic leadership style and has a strong following among Indian voters. However, he also faces criticism from various quarters due to various policies and decisions made during his tenure as Prime Minister.
