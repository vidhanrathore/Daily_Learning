# %%
import requests
import json

url = "http://localhost:11434/api/generate"

data = {
    "model": "mistral",
    "prompt": "Explain Python in simple words",
    "stream": False
}

response = requests.post(url, json=data)

result = response.json()

print(result["response"])
# Out:
#  Python is a programming language that allows computers to understand and execute instructions that we humans write. It's like a translator that helps us communicate with computers more effectively.
#
# In simpler terms, think of Python as a set of building blocks that you can use to create all sorts of things, from simple games to complex websites or even artificial intelligence applications. You arrange these blocks (which are called "functions" and "libraries" in programming) in a specific order to tell the computer what to do.
#
# Python is popular because it's easy for beginners to learn due to its clear syntax (the way it's written), yet powerful enough for professional programmers to create complex software solutions. It also has a large community of developers which means there are plenty of resources available online to help you learn and solve problems.

# %%
import requests
import json
def get_response(q="hi"):
    url = "http://localhost:11434/api/generate"

    data = {
        "model": "mistral",
        "prompt": q,
        "stream": False
    }

    response = requests.post(url, json=data)

    result = response.json()

    print(result["response"])

# %%
get_response()
# Out:
#  Hello! How can I help you today? If you have any questions or need assistance with something, feel free to ask. I'm here to help.

# %%
get_response("who is elon musk")
# Out:
#  Elon Musk is a South African-born American entrepreneur, businessman, and engineer. He is the CEO of SpaceX, co-founder, CEO, and product architect of Tesla, Inc., founder of Neuralink, and co-founder of The Boring Company.
#
# Musk is widely known for his work on advanced electric vehicles, renewable energy, and space travel technology. He has been a significant figure in the development and popularization of commercial space travel through SpaceX, which was founded in 2002 to reduce space transportation costs and enable the colonization of Mars.
#
# Tesla, Inc., founded in 2003, is one of the world's leading manufacturers of electric vehicles. Under Musk's leadership, Tesla has also made significant advancements in battery technology and renewable energy solutions.
#
# Neuralink, founded in 2016, is a neurotechnology company that aims to develop brain-machine interfaces to help treat various neurological conditions, as well as enhance human cognition. The Boring Company, established in 2016, focuses on infrastructure projects related to tunnel construction and transportation innovation.
#
# Elon Musk's accomplishments have earned him recognition as one of the most influential people in the world by Time Magazine (2020) and Fortune (2021).
